# %%
import pandas as pd

# %%
#2 main datatype
series=pd.Series(["BMW","Toyota","Honda"])
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series=1-dimensonal
colours=pd.Series(["red","black","white"])
colours
# Out:
# 0      red
# 1    black
# 2    white
# dtype: object

# %%
car_data=pd.DataFrame({"Car_maker":series,"Car_Colour":colours})
car_data
# Out:
#   Car_maker Car_Colour
# 0       BMW        red
# 1    Toyota      black
# 2     Honda      white

# %%
carsale=pd.read_csv("/home/hadoop/car.csv")

# %%
carsale
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
#export data frame
carsale.to_csv("newCarData.csv",index=False)

# %%
l=pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")

# %%
l
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
carsale.dtypes
# Out:
# year             int64
# model           object
# price            int64
# mileage          int64
# color           object
# transmission    object
# dtype: object

# %%
column=carsale.columns
column
# Out:
# Index(['year', 'model', 'price', 'mileage', 'color', 'transmission'], dtype='object')

# %%
carsale.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
carsale.describe
# Out:
# <bound method NDFrame.describe of      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]>

# %%
carsale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          150 non-null    int64
#  1   model         150 non-null    object
#  2   price         150 non-null    int64
#  3   mileage       150 non-null    int64
#  4   color         150 non-null    object
#  5   transmission  150 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 7.2+ KB

# %%
carsale.mean()
# Out:
# year        2008.726667
# price      12961.933333
# mileage    44260.646667
# dtype: float64

# %%
carsale.sum()
# Out:
# year                                                       301309
# model           SELSELSELSELSESELSELSELSESSESSESSESSELSESSESES...
# price                                                     1944290
# mileage                                                   6639097
# color           YellowGraySilverGrayWhiteSilverBlueSilverSilve...
# transmission    AUTOAUTOAUTOAUTOAUTOAUTOAUTOAUTOAUTOAUTOAUTOAU...
# dtype: object

# %%
carsale["price"].sum()
# Out:
# 1944290

# %%
carsale.tail()
# Out:
#      year model  price  mileage   color transmission
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO

# %%
animal=pd.Series(["cat","dog","hean","panda","crow"],index=[0,3,9,8,3])
animal
# Out:
# 0      cat
# 3      dog
# 9     hean
# 8    panda
# 3     crow
# dtype: object

# %%
animal.loc[3]
# Out:
# 3     dog
# 3    crow
# dtype: object

# %%
animal.loc[9]
# Out:
# 'hean'

# %%
carsale.loc[3]
# Out:
# year             2011
# model             SEL
# price           17809
# mileage         11613
# color            Gray
# transmission     AUTO
# Name: 3, dtype: object

# %%
animal.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    hean
# dtype: object

# %%
carsale.iloc[3]
# Out:
# year             2011
# model             SEL
# price           17809
# mileage         11613
# color            Gray
# transmission     AUTO
# Name: 3, dtype: object

# %%
animal.loc[:9]
# Out:
# 0     cat
# 3     dog
# 9    hean
# dtype: object

# %%
animal
# Out:
# 0      cat
# 3      dog
# 9     hean
# 8    panda
# 3     crow
# dtype: object

# %%
carsale["price"]
# Out:
# 0      21992
# 1      20995
# 2      19995
# 3      17809
# 4      17500
#        ...
# 145     6200
# 146     5995
# 147     5980
# 148     4899
# 149     3800
# Name: price, Length: 150, dtype: int64

# %%
carsale["color"]
# Out:
# 0      Yellow
# 1        Gray
# 2      Silver
# 3        Gray
# 4       White
#         ...
# 145    Silver
# 146       Red
# 147       Red
# 148    Yellow
# 149       Red
# Name: color, Length: 150, dtype: object

# %%
carsale[carsale["color"]=="Gray"]
# Out:
#      year model  price  mileage color transmission
# 1    2011   SEL  20995    10926  Gray         AUTO
# 3    2011   SEL  17809    11613  Gray         AUTO
# 28   2010   SES  15298    22029  Gray         AUTO
# 41   2010   SES  14699    36469  Gray         AUTO
# 48   2009   SEL  14477    29501  Gray       MANUAL
# 61   2010   SES  13992    26716  Gray       MANUAL
# 67   2010    SE  13895    48174  Gray         AUTO
# 72   2010   SEL  13687    35574  Gray         AUTO
# 77   2010    SE  13384    41342  Gray         AUTO
# 88   2009    SE  12995    53902  Gray         AUTO
# 90   2009    SE  12992    27136  Gray         AUTO
# 92   2009    SE  12988    31538  Gray         AUTO
# 98   2009    SE  12507    44789  Gray         AUTO
# 113  2009   SEL  10995    78264  Gray         AUTO
# 115  2008    SE  10955    39643  Gray         AUTO
# 143  2004   SES   6980   101130  Gray         AUTO

# %%
pd.crosstab(carsale["color"],carsale["transmission"])
# Out:
# transmission  AUTO  MANUAL
# color
# Black           26       9
# Blue            17       0
# Gold             1       0
# Gray            14       2
# Green            4       1
# Red             24       1
# Silver          28       4
# White           12       4
# Yellow           2       1

# %%
l=carsale.groupby(["color"]).mean()

# %%
l
# Out:
#                year         price       mileage
# color
# Black   2009.257143  13314.828571  39198.571429
# Blue    2009.176471  13690.588235  33767.588235
# Gold    2009.000000  10955.000000  40180.000000
# Gray    2009.250000  13665.500000  39921.625000
# Green   2007.800000  12110.000000  34264.400000
# Red     2007.440000  11458.800000  58995.720000
# Silver  2008.968750  13615.968750  41075.875000
# White   2008.812500  12394.187500  50815.062500
# Yellow  2006.333333  11630.000000  80162.666667

# %%
l["price"].plot()

# %%
carsale["price"].plot()

# %%
carsale["price"].hist()

# %%
l["price"].hist()

# %%
covid=pd.read_csv("/home/hadoop/covid.csv")

# %%
covid
# Out:
#          SNo ObservationDate Province/State         Country  \
# 0          1      01/22/2020          Anhui  Mainland China
# 1          2      01/22/2020        Beijing  Mainland China
# 2          3      01/22/2020      Chongqing  Mainland China
# 3          4      01/22/2020         Fujian  Mainland China
# 4          5      01/22/2020          Gansu  Mainland China
# ...      ...             ...            ...             ...
# 12564  12565      04/06/2020        Wyoming              US
# 12565  12566      04/06/2020       Xinjiang  Mainland China
# 12566  12567      04/06/2020          Yukon          Canada
# 12567  12568      04/06/2020         Yunnan  Mainland China
# 12568  12569      04/06/2020       Zhejiang  Mainland China
#
#                Last Update  Confirmed  Deaths  Recovered
# 0          1/22/2020 17:00          1       0          0
# 1          1/22/2020 17:00         14       0          0
# 2          1/22/2020 17:00          6       0          0
# ...

# %%
covidIndData=covid[covid["Country"]=="India"]
covidItalyData=covid[covid["Country"]=="Italy"]
covidSpainData=covid[covid["Country"]=="Spain"]
covidChainaData=covid[covid["Country"]=="Mainland China"]
Pakistan=covid[covid["Country"]=="Pakistan"]

# %%
covidSpainData.tail()
# Out:
#          SNo ObservationDate Province/State Country          Last Update  \
# 11135  11136      04/02/2020            NaN   Spain  2020-04-02 23:32:01
# 11450  11451      04/03/2020            NaN   Spain  2020-04-03 22:52:45
# 11765  11766      04/04/2020            NaN   Spain  2020-04-04 23:41:02
# 12082  12083      04/05/2020            NaN   Spain  2020-04-05 23:13:44
# 12402  12403      04/06/2020            NaN   Spain  2020-04-06 23:28:35
#
#        Confirmed  Deaths  Recovered
# 11135     112065   10348      26743
# 11450     119199   11198      30513
# 11765     126168   11947      34219
# 12082     131646   12641      38080
# 12402     136675   13341      40437

# %%
#covidIndData["Confirmed"].hist()
#ax = plt.gca()
import matplotlib.pyplot as plt
ax = plt.gca()
font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16,
        }
plt.xlabel('Date and Time',fontdict=font)
plt.ylabel('Number Of Confirmed cases of Covid-19',fontdict=font)
plt.title('Covid-19 Data Analysis Among Countrys',fontdict=font)
plt.text(55, 10, r'$INDIA$', fontdict=font)
plt.legend()
#plt.text(55, 3, r'$INDIA$', fontdict=font)
#fig.set_size_inches(30.5, 20.5)
covidIndData.plot(x='Last Update',y='Confirmed',label='INDIA',color='Black',figsize=(16,10),ax=ax)
covidItalyData.plot(x='Last Update',y='Confirmed',color='red',label='ITALY',ax=ax)
covidSpainData.plot(x='Last Update',y='Confirmed',color='blue',label='SPAIN',ax=ax)
#Pakistan.plot(x='Last Update',y='Confirmed',color='green',label='PAKISTAN',ax=ax)

#covidChainaData.plot(x='Last Update',y='Confirmed',color='brown',figsize=(27,8),ax=ax)
#df.plot(kind='line',x='DeviceID',y='VoltageC',color='red',ax=ax)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # Mamupulation

# %%
carsale["model"]=carsale["model"].str.lower()

# %%
carsale
# Out:
#      year model  price  mileage   color transmission
# 0    2011   sel  21992     7413  Yellow         AUTO
# 1    2011   sel  20995    10926    Gray         AUTO
# 2    2011   sel  19995     7351  Silver         AUTO
# 3    2011   sel  17809    11613    Gray         AUTO
# 4    2012    se  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   ses   6200    95000  Silver         AUTO
# 146  2002    se   5995    87003     Red         AUTO
# 147  2000    se   5980    96841     Red         AUTO
# 148  2001    se   4899   151479  Yellow         AUTO
# 149  2000    se   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
carsale
# Out:
#      year model  price  mileage   color transmission
# 0    2011   sel  21992     7413  Yellow         AUTO
# 1    2011   sel  20995    10926    Gray         AUTO
# 2    2011   sel  19995     7351  Silver         AUTO
# 3    2011   sel  17809    11613    Gray         AUTO
# 4    2012    se  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   ses   6200    95000  Silver         AUTO
# 146  2002    se   5995    87003     Red         AUTO
# 147  2000    se   5980    96841     Red         AUTO
# 148  2001    se   4899   151479  Yellow         AUTO
# 149  2000    se   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
#column from series
pkcolumn=pd.Series([7,3,1,2,5,7,3,90])

# %%
carsale["seat"]=pkcolumn;

# %%
carsale["seat"]=carsale.fillna(carsale["seat"].mean())

# %%
carsale
# Out:
#      year model  price  mileage   color transmission  seat
# 0    2011   sel  21992     7413  Yellow         AUTO  2011
# 1    2011   sel  20995    10926    Gray         AUTO  2011
# 2    2011   sel  19995     7351  Silver         AUTO  2011
# 3    2011   sel  17809    11613    Gray         AUTO  2011
# 4    2012    se  17500     8367   White         AUTO  2012
# ..    ...   ...    ...      ...     ...          ...   ...
# 145  2006   ses   6200    95000  Silver         AUTO  2006
# 146  2002    se   5995    87003     Red         AUTO  2002
# 147  2000    se   5980    96841     Red         AUTO  2000
# 148  2001    se   4899   151479  Yellow         AUTO  2001
# 149  2000    se   3800   109259     Red         AUTO  2000
#
# [150 rows x 7 columns]

# %%
carsale.drop("seat",axis=1,inplace=True)

# %%
carsale
# Out:
#      year model  price  mileage   color transmission
# 0    2011   sel  21992     7413  Yellow         AUTO
# 1    2011   sel  20995    10926    Gray         AUTO
# 2    2011   sel  19995     7351  Silver         AUTO
# 3    2011   sel  17809    11613    Gray         AUTO
# 4    2012    se  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   ses   6200    95000  Silver         AUTO
# 146  2002    se   5995    87003     Red         AUTO
# 147  2000    se   5980    96841     Red         AUTO
# 148  2001    se   4899   151479  Yellow         AUTO
# 149  2000    se   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
carsale["tt"]=5

# %%
carsale
# Out:
#      year model  price  mileage   color transmission  tt
# 0    2011   sel  21992     7413  Yellow         AUTO   5
# 1    2011   sel  20995    10926    Gray         AUTO   5
# 2    2011   sel  19995     7351  Silver         AUTO   5
# 3    2011   sel  17809    11613    Gray         AUTO   5
# 4    2012    se  17500     8367   White         AUTO   5
# ..    ...   ...    ...      ...     ...          ...  ..
# 145  2006   ses   6200    95000  Silver         AUTO   5
# 146  2002    se   5995    87003     Red         AUTO   5
# 147  2000    se   5980    96841     Red         AUTO   5
# 148  2001    se   4899   151479  Yellow         AUTO   5
# 149  2000    se   3800   109259     Red         AUTO   5
#
# [150 rows x 7 columns]

# %%
carsale=carsale.sample(frac=0.2)

# %%
carsale
# Out:
#      year model  price  mileage   color transmission  tt
# 43   2009   ses  14549    34046  Silver         AUTO   5
# 79   2010    se  13350    16573    Blue         AUTO   5
# 132  2008    se   8495   106171   Black         AUTO   5
# 8    2011   ses  16995    32655  Silver         AUTO   5
# 133  2008    se   8494    68901  Silver         AUTO   5
# 55   2010    se  13995    13541  Silver         AUTO   5
# 4    2012    se  17500     8367   White         AUTO   5
# 44   2010    se  14499    32703     Red         AUTO   5
# 64   2009    se  13950     9450   Black         AUTO   5
# 72   2010   sel  13687    35574    Gray         AUTO   5
# 128  2007   ses   9000    80605     Red         AUTO   5
# 53   2009    se  13999    23785     Red         AUTO   5
# 6    2011   sel  17000    27393    Blue         AUTO   5
# 73   2009   sel  13663    27528  Silver         AUTO   5
# 46   2010    se  14495    38275   Black         AUTO   5
# ...

# %%
carsale=carsale.reset_index(drop=True)

# %%
carsale
# Out:
#     year model  price  mileage   color transmission  tt
# 0   2009   ses  14549    34046  Silver         AUTO   5
# 1   2010    se  13350    16573    Blue         AUTO   5
# 2   2008    se   8495   106171   Black         AUTO   5
# 3   2011   ses  16995    32655  Silver         AUTO   5
# 4   2008    se   8494    68901  Silver         AUTO   5
# 5   2010    se  13995    13541  Silver         AUTO   5
# 6   2012    se  17500     8367   White         AUTO   5
# 7   2010    se  14499    32703     Red         AUTO   5
# 8   2009    se  13950     9450   Black         AUTO   5
# 9   2010   sel  13687    35574    Gray         AUTO   5
# 10  2007   ses   9000    80605     Red         AUTO   5
# 11  2009    se  13999    23785     Red         AUTO   5
# 12  2011   sel  17000    27393    Blue         AUTO   5
# 13  2009   sel  13663    27528  Silver         AUTO   5
# 14  2010    se  14495    38275   Black         AUTO   5
# 15  2006   ses   6200    95000  Silver         AUTO   5
# ...

# %%
carsale["price"]=carsale["price"].apply(lambda x:x/2)

# %%
carsale
# Out:
#     year model   price  mileage   color transmission  tt
# 0   2009   ses  7274.5    34046  Silver         AUTO   5
# 1   2010    se  6675.0    16573    Blue         AUTO   5
# 2   2008    se  4247.5   106171   Black         AUTO   5
# 3   2011   ses  8497.5    32655  Silver         AUTO   5
# 4   2008    se  4247.0    68901  Silver         AUTO   5
# 5   2010    se  6997.5    13541  Silver         AUTO   5
# 6   2012    se  8750.0     8367   White         AUTO   5
# 7   2010    se  7249.5    32703     Red         AUTO   5
# 8   2009    se  6975.0     9450   Black         AUTO   5
# 9   2010   sel  6843.5    35574    Gray         AUTO   5
# 10  2007   ses  4500.0    80605     Red         AUTO   5
# 11  2009    se  6999.5    23785     Red         AUTO   5
# 12  2011   sel  8500.0    27393    Blue         AUTO   5
# 13  2009   sel  6831.5    27528  Silver         AUTO   5
# 14  2010    se  7247.5    38275   Black         AUTO   5
# ...

# %%
def ll():
    print(carsale)

# %%
ll()
# Out:
#     year model   price  mileage   color transmission  tt
# 0   2009   ses  7274.5    34046  Silver         AUTO   5
# 1   2010    se  6675.0    16573    Blue         AUTO   5
# 2   2008    se  4247.5   106171   Black         AUTO   5
# 3   2011   ses  8497.5    32655  Silver         AUTO   5
# 4   2008    se  4247.0    68901  Silver         AUTO   5
# 5   2010    se  6997.5    13541  Silver         AUTO   5
# 6   2012    se  8750.0     8367   White         AUTO   5
# 7   2010    se  7249.5    32703     Red         AUTO   5
# 8   2009    se  6975.0     9450   Black         AUTO   5
# 9   2010   sel  6843.5    35574    Gray         AUTO   5
# 10  2007   ses  4500.0    80605     Red         AUTO   5
# 11  2009    se  6999.5    23785     Red         AUTO   5
# 12  2011   sel  8500.0    27393    Blue         AUTO   5
# 13  2009   sel  6831.5    27528  Silver         AUTO   5
# 14  2010    se  7247.5    38275   Black         AUTO   5
# ...

# %% [markdown]
# # numpy operation

# %%
#introduction of num py
#numeriacl python is ca;ll numm py
